# %%
import pandas as pd

# %%
ukraine=pd.read_csv('ukraine.csv')

# %%
ukraine.head()
# Out:
#             Date date publised_date total_death total_death_men  \
# 0   7 March 2022  NaN           474          97              54
# 1   8 March 2022  NaN           516          98              60
# 2   9 March 2022  NaN           549         101              67
# 3  10 March 2022  NaN           564         106              73
# 4  11 March 2022  NaN           564         106              73
#
#    total_death_women  total_death_girls  total_death_boys  \
# 0                  4                  8                17
# 1                  5                  9                23
# 2                  6                  9                26
# 3                  6                  9                26
# 4                  6                  9                27
#
#   total_death_children total_death_adults  ... casaulties_gov_ctrl  \
# 0                  294                861  ...                  72
# 1                  321                908  ...                  87
# ...

# %%
ukraine.tail()
# Out:
#             Date          date publised_date total_death total_death_men  \
# 84  21 June 2022           NAN         4,634       1,780           1,194
# 85  22 June 2022           NAN         4,662       1,789           1,207
# 86  23 June 2022  24 June 2022         4,677       1,793           1,208
# 87  26 June 2022  27 June 2022         4,731       1,812           1,225
# 88   3 July 2022   4 July 2022         4,889       1,862           1,264
#
#     total_death_women  total_death_girls  total_death_boys  \
# 84                131                148                41
# 85                131                148                41
# 86                132                148                41
# 87                134                155                41
# 88                137                157                41
#
#    total_death_children total_death_adults  ... casaulties_gov_ctrl  \
# 84                1,340              5,769  ...               2,524
# ...
